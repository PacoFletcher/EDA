# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
ipc_abs = pd.read_csv("Data/ipc_abs.csv", sep = ";", encoding = "Windows 1250")
ipc_abs
# Out:
#    Comunidades y Ciudades Autónomas  \
# 0                     16 País Vasco
# 1                     16 País Vasco
# 2                     16 País Vasco
# 3                     16 País Vasco
# 4                     16 País Vasco
# 5                     16 País Vasco
# 6                     16 País Vasco
# 7                     16 País Vasco
# 8                     16 País Vasco
# 9                     16 País Vasco
# 10                    16 País Vasco
# 11                    16 País Vasco
# 12                    16 País Vasco
# 13                    16 País Vasco
# 14                    16 País Vasco
# 15                    16 País Vasco
# 16                    16 País Vasco
# 17                    16 País Vasco
# 18                    16 País Vasco
# 19                    16 País Vasco
# 20                    16 País Vasco
# 21                    16 País Vasco
# 22                    16 País Vasco
# 23                    16 País Vasco
# 24                    16 País Vasco
# ...

# %%
ipc_abs["Total"] = ipc_abs["Total"].str.replace(",",".").astype(float)

# %%
ipc_abs["Periodo"] = pd.to_datetime(ipc_abs["Periodo"], format = "%Y")

# %%
ipc_abs
# Out:
#    Comunidades y Ciudades Autónomas  \
# 0                     16 País Vasco
# 1                     16 País Vasco
# 2                     16 País Vasco
# 3                     16 País Vasco
# 4                     16 País Vasco
# 5                     16 País Vasco
# 6                     16 País Vasco
# 7                     16 País Vasco
# 8                     16 País Vasco
# 9                     16 País Vasco
# 10                    16 País Vasco
# 11                    16 País Vasco
# 12                    16 País Vasco
# 13                    16 País Vasco
# 14                    16 País Vasco
# 15                    16 País Vasco
# 16                    16 País Vasco
# 17                    16 País Vasco
# 18                    16 País Vasco
# 19                    16 País Vasco
# 20                    16 País Vasco
# 21                    16 País Vasco
# 22                    16 País Vasco
# 23                    16 País Vasco
# 24                    16 País Vasco
# ...

# %%
ipc_abs.to_csv("Data/ipc_abs_ok.csv", sep = ",", index = False)
