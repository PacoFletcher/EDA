# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from dateutil import parser

# %%
bilbo = pd.read_csv("Data/renta_bilbo.csv")
bilbo["Año"] = pd.to_datetime(bilbo["Año"])
bilbo.dtypes
# Out:
# Año                           datetime64[ns]
# Renta total                          float64
# Renta del trabajo                    float64
# Renta capital mobiliario             float64
# Renta capital inmobiliario           float64
# Renta de actividades                 float64
# Transferencias                       float64
# Renta disponible                     float64
# Distrito                              object
# dtype: object

# %%
ipc = pd.read_csv("Data/ipc_ok.csv")
ipc["Mes"] = pd.to_datetime(ipc["Mes"])
ipc
# Out:
# C:\Users\pacof\AppData\Local\Temp\ipykernel_12820\1580206100.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ipc["Mes"] = pd.to_datetime(ipc["Mes"])
#       Unnamed: 0        Mes Precio m2 Variación mensual Variación trimestral  \
# 0              0 2025-01-02      15.0             0,00%                 2.4%
# 1              1 2025-01-01      15.0              0.8%                 5.7%
# 2              2 2024-01-12      14.9              1.6%                 6.3%
# 3              3 2024-01-11      14.6              3.2%                 5.5%
# 4              4 2024-01-10      14.2              1.4%                 1.8%
# ...          ...        ...       ...               ...                  ...
# 2297        2297 2006-01-05      n.d.              n.d.                 n.d.
# ...

# %%
ipc_abs = pd.read_csv("Data/ipc_abs_ok.csv", sep = ",")
ipc_abs
# Out:
#    Comunidades y Ciudades Autónomas  \
# 0                     16 País Vasco
# 1                     16 País Vasco
# 2                     16 País Vasco
# 3                     16 País Vasco
# 4                     16 País Vasco
# 5                     16 País Vasco
# 6                     16 País Vasco
# 7                     16 País Vasco
# 8                     16 País Vasco
# 9                     16 País Vasco
# 10                    16 País Vasco
# 11                    16 País Vasco
# 12                    16 País Vasco
# 13                    16 País Vasco
# 14                    16 País Vasco
# 15                    16 País Vasco
# 16                    16 País Vasco
# 17                    16 País Vasco
# 18                    16 País Vasco
# 19                    16 País Vasco
# 20                    16 País Vasco
# 21                    16 País Vasco
# 22                    16 País Vasco
# 23                    16 País Vasco
# 24                    16 País Vasco
# ...

# %%
ipc_abs["Periodo"] = pd.to_datetime(ipc_abs["Periodo"])
ipc_abs.sort_values(["Grupos ECOICOP","Periodo"], ascending = [False,True], inplace=True)
ipc_abs
# Out:
#    Comunidades y Ciudades Autónomas  \
# 22                    16 País Vasco
# 21                    16 País Vasco
# 20                    16 País Vasco
# 19                    16 País Vasco
# 18                    16 País Vasco
# 17                    16 País Vasco
# 16                    16 País Vasco
# 15                    16 País Vasco
# 14                    16 País Vasco
# 13                    16 País Vasco
# 12                    16 País Vasco
# 11                    16 País Vasco
# 10                    16 País Vasco
# 9                     16 País Vasco
# 8                     16 País Vasco
# 7                     16 País Vasco
# 6                     16 País Vasco
# 5                     16 País Vasco
# 4                     16 País Vasco
# 3                     16 País Vasco
# 2                     16 País Vasco
# 1                     16 País Vasco
# 0                     16 País Vasco
# 45                    16 País Vasco
# 44                    16 País Vasco
# ...

# %%
ipc_abs.rename(columns={"Grupos ECOICOP":"Grupo"}, inplace=True)

# %%
ipc_abs.columns
# Out:
# Index(['Comunidades y Ciudades Autónomas', 'Grupo', 'Periodo', 'Total'], dtype='object')

# %%
val_2006_gen = ipc_abs[(ipc_abs["Periodo"].dt.year == 2006) & (ipc_abs["Grupo"] == "Índice general")]["Total"]
v_g_2006 = val_2006_gen.iloc[0]
v_g_2006
# Out:
# np.float64(79.46)

# %%
val_2006_viv = ipc_abs[(ipc_abs["Periodo"].dt.year == 2006) & (ipc_abs["Grupo"] == "04 Vivienda, agua, electricidad, gas y otros combustibles")]["Total"]
v_v_2006 = val_2006_viv.iloc[0]
v_v_2006
# Out:
# np.float64(69.226)

# %%
var_an = (ipc_abs[ipc_abs["Grupo"] == "Índice general"]["Total"]-v_g_2006)/v_g_2006*100
var_an
# Out:
# 22   -11.627234
# 21    -9.131639
# 20    -6.376793
# 19    -3.292223
# 18     0.000000
# 17     2.847974
# 16     7.068966
# 15     7.357161
# 14     9.173169
# 13    12.552228
# 12    15.154795
# 11    16.968286
# 10    17.157060
# 9     16.844953
# 8     16.861314
# 7     19.179461
# 6     21.086081
# 5     22.245155
# 4     22.076516
# 3     25.849484
# 2     35.979109
# 1     40.903599
# 0     45.215203
# Name: Total, dtype: float64

# %%
var_viv_an = (ipc_abs[ipc_abs["Grupo"] == "04 Vivienda, agua, electricidad, gas y otros combustibles"]["Total"]-v_v_2006)/v_v_2006*100
var_viv_an
# Out:
# 45   -16.415798
# 44   -13.984630
# 43   -10.340046
# 42    -5.880738
# 41     0.000000
# 40     3.588247
# 39    10.175368
# 38    12.243955
# 37    15.697859
# 36    24.736371
# 35    31.821859
# 34    33.218733
# 33    35.840580
# 32    33.579869
# 31    28.055933
# 30    32.768035
# 29    36.148268
# 28    34.153353
# 27    29.750383
# 26    44.454396
# 25    67.279635
# 24    47.229365
# 23    52.692630
# Name: Total, dtype: float64

# %%
var_an = pd.concat([var_an,var_viv_an], axis = 0)
var_2006 = {"Var_2006":var_an}
var_2006 = pd.DataFrame(var_2006)

# %%
var_2006
# Out:
#      Var_2006
# 22 -11.627234
# 21  -9.131639
# 20  -6.376793
# 19  -3.292223
# 18   0.000000
# 17   2.847974
# 16   7.068966
# 15   7.357161
# 14   9.173169
# 13  12.552228
# 12  15.154795
# 11  16.968286
# 10  17.157060
# 9   16.844953
# 8   16.861314
# 7   19.179461
# 6   21.086081
# 5   22.245155
# 4   22.076516
# 3   25.849484
# 2   35.979109
# 1   40.903599
# 0   45.215203
# 45 -16.415798
# 44 -13.984630
# 43 -10.340046
# 42  -5.880738
# 41   0.000000
# 40   3.588247
# 39  10.175368
# 38  12.243955
# 37  15.697859
# 36  24.736371
# 35  31.821859
# 34  33.218733
# 33  35.840580
# 32  33.579869
# 31  28.055933
# 30  32.768035
# 29  36.148268
# 28  34.153353
# 27  29.750383
# 26  44.454396
# 25  67.279635
# 24  47.229365
# 23  52.692630

# %%
ipc_abs = pd.concat([ipc_abs,var_2006], axis = 1)

# %%
ipc_abs
# Out:
#    Comunidades y Ciudades Autónomas  \
# 22                    16 País Vasco
# 21                    16 País Vasco
# 20                    16 País Vasco
# 19                    16 País Vasco
# 18                    16 País Vasco
# 17                    16 País Vasco
# 16                    16 País Vasco
# 15                    16 País Vasco
# 14                    16 País Vasco
# 13                    16 País Vasco
# 12                    16 País Vasco
# 11                    16 País Vasco
# 10                    16 País Vasco
# 9                     16 País Vasco
# 8                     16 País Vasco
# 7                     16 País Vasco
# 6                     16 País Vasco
# 5                     16 País Vasco
# 4                     16 País Vasco
# 3                     16 País Vasco
# 2                     16 País Vasco
# 1                     16 País Vasco
# 0                     16 País Vasco
# 45                    16 País Vasco
# 44                    16 País Vasco
# ...

# %%
bilbo[bilbo["Distrito"] == "BILBAO" ]["Renta total"][1:]
# Out:
# 1     20081.0
# 2     19787.0
# 3     19717.0
# 4     19761.0
# 5     20313.0
# 6     20526.0
# 7     21245.0
# 8     21538.0
# 9     22659.0
# 10    22464.0
# 11    23592.0
# 12    25366.0
# Name: Renta total, dtype: float64

# %%
def variacion(df,bar,col):
    print(col)
    var = [0]
    j = df[df["Distrito"] == bar][col][0]
    for i in df[df["Distrito"] == bar][col][1:]:
        var.append(round((i-j)/i*100,2))
    #var[col] = pd.Series(var)
    print(var)
    return(var)

# %%
var_gen = variacion(bilbo,"BILBAO","Renta total")
#var_gen.append(variacion(bilbo,"BILBAO","Renta total"))
df = bilbo[bilbo["Distrito"] == "BILBAO"]
df["Var_2006"] = var_gen
df
# Out:
# Renta total
# [0, np.float64(9.39), np.float64(8.04), np.float64(7.71), np.float64(7.92), np.float64(10.42), np.float64(11.35), np.float64(14.35), np.float64(15.52), np.float64(19.7), np.float64(19.0), np.float64(22.87), np.float64(28.27)]
# C:\Users\pacof\AppData\Local\Temp\ipykernel_12820\3570742963.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Var_2006"] = var_gen
#           Año  Renta total  Renta del trabajo  Renta capital mobiliario  \
# 0  2006-01-01      18196.0            10749.0                    2315.0
# 1  2009-01-01      20081.0            12285.0                    2000.0
# 2  2011-01-01      19787.0            12062.0                    1717.0
# ...

# %%
df["Año"].iloc[-1].year
# Out:
# 2022

# %%
plt.figure(figsize=(10,9))
sns.lineplot(data = ipc_abs[ipc_abs["Grupo"] == "Índice general"], x = "Periodo", y = "Var_2006", hue = "Grupo", marker = 'o', linewidth = 3)
sns.lineplot(data = df, x = "Año", y = "Var_2006", label = "Evolución Renta Bilbao", marker='o', linewidth = 3)
plt.ylabel("Variacón porcentual respecto 2006")
plt.title("Variación porcentual del IPC y de las rentas en Bilbao respecto 2006")
plt.xlim(df["Año"].iloc[0],df["Año"].iloc[-1]);

# %%
adq = pd.merge(df,ipc_abs[ipc_abs["Grupo"] =="Índice general"],how="left",left_on="Año",right_on="Periodo" )
adq["Diferencia"] = adq["Var_2006_x"] - adq["Var_2006_y"]
adq
# Out:
#           Año  Renta total  Renta del trabajo  Renta capital mobiliario  \
# 0  2006-01-01      18196.0            10749.0                    2315.0
# 1  2009-01-01      20081.0            12285.0                    2000.0
# 2  2011-01-01      19787.0            12062.0                    1717.0
# 3  2013-01-01      19717.0            11735.0                    1613.0
# 4  2014-01-01      19761.0            11737.0                    1484.0
# 5  2015-01-01      20313.0            11734.0                    1403.0
# 6  2016-01-01      20526.0            11855.0                    1467.0
# 7  2017-01-01      21245.0            12448.0                    1343.0
# 8  2018-01-01      21538.0            12571.0                    1394.0
# 9  2019-01-01      22659.0            13304.0                    1441.0
# 10 2020-01-01      22464.0            12656.0                    1357.0
# 11 2021-01-01      23592.0            13491.0                    1461.0
# ...

# %%
adq["Año"].iloc[-1]
# Out:
# Timestamp('2022-01-01 00:00:00')

# %%
adq["Diferencia"].iloc[-1]
# Out:
# np.float64(-7.709108985653177)

# %%
plt.figure(figsize=(10,9))
sns.lineplot(data = adq, x = "Año", y = "Diferencia", marker = 'o', linewidth = 3)
plt.axhline(0, linestyle = ":", color = "r")
#plt.axline((adq["Año"].iloc[0], adq["Diferencia"].iloc[0]),(adq["Año"].iloc[-1], adq["Diferencia"].iloc[-1]))
plt.ylim([-10,10])
plt.title("Ajuste de la renta respecto la inflación");

# %%
renta_2022 = bilbo[bilbo["Año"].dt.year == 2022] 
renta_2022.sort_values("Renta total", ascending=False,inplace=True)
renta_2022["Distrito"]
# Out:
# C:\Users\pacof\AppData\Local\Temp\ipykernel_12820\1881800757.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   renta_2022.sort_values("Renta total", ascending=False,inplace=True)
# 25                       Abando
# 220                    Indautxu
# 168                    Castaños
# 103                     Basurtu
# 155          Casco Viejo Bilbao
# 415         San Pedro de Deustu
# 181               Ciudad Jardín
# 116                      Begoña
# 51                     Ametzola
# 12                       BILBAO
# 207               Ibarrekolanda
# 454                  Txurdinaga
# 246                   Iturralde
# 402                 San Ignacio
# 441                  Solokoetxe
# 233                  Iralabarri
# 311    Masustegi-Monte Caramelo
# 324                      Matiko
# ...

# %%
ranking = pd.DataFrame([])
ranking["2006"] = renta_2006[renta_2006["Distrito"]!= "BILBAO"]["Distrito"].reset_index(drop =True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 2
#       1 ranking = pd.DataFrame([])
# ----> 2 ranking["2006"] = renta_2006[renta_2006["Distrito"]!= "BILBAO"]["Distrito"].reset_index(drop =True)
#
# NameError: name 'renta_2006' is not defined

# %%
ranking
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
colores = []
for i in range(9):
    colores.append("g")
colores.append("b")
for i in range(11,len(renta_2022["Distrito"].unique())):
    colores.append("r")
colores
# Out:
# ['g',
#  'g',
#  'g',
#  'g',
#  'g',
#  'g',
#  'g',
#  'g',
#  'g',
#  'b',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r']

# %%
plt.figure(figsize=(12,10))
sns.barplot(data = renta_2022, x = "Renta total", y = "Distrito", orient = "h", palette = colores)
plt.title("Distritos de mayor a menor renta total en 2022");
# Out:
# C:\Users\pacof\AppData\Local\Temp\ipykernel_12820\299064708.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = renta_2022, x = "Renta total", y = "Distrito", orient = "h", palette = colores)

# %%
top5_bar_up = bilbo[(bilbo["Año"].dt.year == 2022) & (bilbo["Distrito"] != "BILBAO")][["Distrito", "Renta total"]].sort_values("Renta total",ascending=False).head(5)["Distrito"]
print(top5_bar_up)
top_up = bilbo[bilbo["Distrito"].isin(top5_bar_up)]
top_up
# Out:
# 25                 Abando
# 220              Indautxu
# 168              Castaños
# 103               Basurtu
# 155    Casco Viejo Bilbao
# Name: Distrito, dtype: object
#            Año  Renta total  Renta del trabajo  Renta capital mobiliario  \
# 13  2006-01-01      31537.0            16037.0                    7496.0
# 14  2009-01-01      35939.0            21667.0                    5767.0
# 15  2011-01-01      32572.0            18363.0                    5274.0
# 16  2013-01-01      33106.0            18332.0                    5084.0
# 17  2014-01-01      33254.0            18228.0                    4940.0
# ..         ...          ...                ...                       ...
# 216 2018-01-01      36281.0            19782.0                    4887.0
# 217 2019-01-01      37467.0            20596.0                    4660.0
# 218 2020-01-01      36277.0            19695.0                    3959.0
# 219 2021-01-01      38097.0            20554.0                    4536.0
# ...

# %%
def mascara(df):
    triang = df.iloc[:,1:-1].corr()
    masc = np.triu(np.ones_like(triang,dtype=bool),1)
    return(masc)

# %%
f, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(top_up.iloc[:,1:-1].corr(),
            mask = mascara(top_up),
            annot=True,
            linewidths=.5,
            ax=ax,
            vmin=0,
            vmax=1,
            cmap = "Greens")
plt.xlabel("")
plt.ylabel("")
plt.title("Correlación de las rentas en los cinco barrios más ricos");

# %%
top5_bar_low = bilbo[(bilbo["Año"].dt.year == 2022) & (bilbo["Distrito"] != "BILBAO")][["Distrito", "Renta total"]].sort_values("Renta total").head(5)["Distrito"]
top5_bar_low
top_low = bilbo[bilbo["Distrito"].isin(top5_bar_low)]
top_low
# Out:
#            Año  Renta total  Renta del trabajo  Renta capital mobiliario  \
# 26  2006-01-01      11660.0             6832.0                     534.0
# 27  2009-01-01      13172.0             7570.0                     483.0
# 28  2011-01-01      12629.0             7272.0                     270.0
# 29  2013-01-01      12632.0             7205.0                     299.0
# 30  2014-01-01      12509.0             6989.0                     254.0
# ..         ...          ...                ...                       ...
# 463 2018-01-01      12064.0             6474.0                     124.0
# 464 2019-01-01      12747.0             7124.0                     149.0
# 465 2020-01-01      12792.0             6589.0                      79.0
# 466 2021-01-01      13272.0             7237.0                      93.0
# 467 2022-01-01      14092.0             7860.0                     112.0
#
#      Renta capital inmobiliario  Renta de actividades  Transferencias  \
# ...

# %%
f, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(top_low.iloc[:,1:-1].corr(),
            mask = mascara(top_low),
            annot=True,
            linewidths=.5,
            ax=ax,
            vmin=0,
            vmax=1,
            cmap = "Greens")
plt.xlabel("")
plt.ylabel("")
plt.title("Correlación de las rentas en los cinco barrios más pobres");

# %%
plt.figure(figsize=(10,9))
sns.lineplot(data = top_up, x = "Año", y = "Renta total", hue = "Distrito")
sns.lineplot(data = top_low, x = "Año", y = "Renta total", hue = "Distrito")
sns.lineplot(data = bilbo[bilbo["Distrito"] == "BILBAO"], x = "Año", y = "Renta total", linewidth= 5, label = "BILBAO")
plt.legend(framealpha = 0, frameon = True, loc = "upper left");

# %%
var_an = bilbo[["Año","Distrito"]]
var_an
# Out:
#            Año  Distrito
# 0   2006-01-01    BILBAO
# 1   2009-01-01    BILBAO
# 2   2011-01-01    BILBAO
# 3   2013-01-01    BILBAO
# 4   2014-01-01    BILBAO
# ..         ...       ...
# 515 2018-01-01  Zurbaran
# 516 2019-01-01  Zurbaran
# 517 2020-01-01  Zurbaran
# 518 2021-01-01  Zurbaran
# 519 2022-01-01  Zurbaran
#
# [520 rows x 2 columns]

# %%
prueba = bilbo[bilbo["Distrito"] == "BILBAO"]
x = [0]
j = 0
for i in prueba["Renta total"][1:].index:
    print(j,i)
    print((prueba["Renta total"][i]-prueba["Renta total"][j])/prueba["Renta total"][j]*100)
    print(round((prueba["Renta total"][i]-prueba["Renta total"][j])/prueba["Renta total"][j]*100,2))
    x.append(round((prueba["Renta total"][i]-prueba["Renta total"][j])/prueba["Renta total"][j]*100,2))
prueba["Var_an"] = x
prueba
# Out:
# 0 1
# 10.359419652670915
# 10.36
# 0 2
# 8.74367992965487
# 8.74
# 0 3
# 8.35897999560343
# 8.36
# 0 4
# 8.600791382721477
# 8.6
# 0 5
# 11.63442514838426
# 11.63
# 0 6
# 12.805012090569356
# 12.81
# 0 7
# 16.756429984612005
# 16.76
# 0 8
# 18.366673994284458
# 18.37
# 0 9
# 24.527368652451088
# 24.53
# 0 10
# 23.455704550450648
# 23.46
# 0 11
# 29.65486920202242
# 29.65
# 0 12
# 39.40426467355463
# 39.4
# C:\Users\pacof\AppData\Local\Temp\ipykernel_12820\555674126.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prueba["Var_an"] = x
#           Año  Renta total  Renta del trabajo  Renta capital mobiliario  \
# 0  2006-01-01      18196.0            10749.0                    2315.0
# ...

# %%
plt.figure(figsize=(10,9))
sns.lmplot(data = bilbo[bilbo["Distrito"] != "BILBAO"], x = "Renta del trabajo", y = "Renta total")

plt.xlim(0,30000)
plt.ylim(0,50000);

# %%
plt.figure(figsize=(10,9))
sns.lmplot(data = bilbo[bilbo["Distrito"] != "BILBAO"], x = "Renta capital mobiliario", y = "Renta total")
plt.ylim(0,50000);

# %%
plt.figure(figsize=(10,9))
sns.lmplot(data = bilbo[bilbo["Distrito"] != "BILBAO"], x = "Renta capital inmobiliario", y = "Renta total")
plt.ylim(0,50000);

# %%
plt.figure(figsize=(10,9))
sns.lmplot(data = bilbo[bilbo["Distrito"] != "BILBAO"], x = "Renta de actividades", y = "Renta total")
plt.ylim(0,50000);

# %%
plt.figure(figsize=(10,9))
sns.lmplot(data = bilbo[bilbo["Distrito"] != "BILBAO"], x = "Transferencias", y = "Renta total")
plt.ylim(0,50000);

# %%
comp = top_up[(top_up["Año"].dt.year.isin((2011,2022)))]
melt_up = comp.melt(id_vars=["Año", "Distrito"])
comp
# Out:
#            Año  Renta total  Renta del trabajo  Renta capital mobiliario  \
# 15  2011-01-01      32572.0            18363.0                    5274.0
# 25  2022-01-01      47044.0            24774.0                    7893.0
# 93  2011-01-01      21666.0            13351.0                    1930.0
# 103 2022-01-01      28775.0            17232.0                    1633.0
# 145 2011-01-01      22409.0            15698.0                    1665.0
# 155 2022-01-01      28350.0            18520.0                    1247.0
# 158 2011-01-01      27482.0            16696.0                    2619.0
# 168 2022-01-01      32469.0            17068.0                    3196.0
# 210 2011-01-01      32461.0            17377.0                    5334.0
# 220 2022-01-01      41750.0            22412.0                    5780.0
#
#      Renta capital inmobiliario  Renta de actividades  Transferencias  \
# 15                       1127.0                2562.0          5246.0
# ...

# %%
fin = comp[comp.columns[1:7]].iloc[1::2].reset_index()
ini = comp[comp.columns[1:7]].iloc[0::2].reset_index()
plot_up = ((fin-ini)/ini*100).mean().round(2)
plot_up
# Out:
# index                         19.08
# Renta total                   30.10
# Renta del trabajo             22.63
# Renta capital mobiliario       7.91
# Renta capital inmobiliario    55.53
# Renta de actividades          23.94
# Transferencias                65.36
# dtype: float64

# %%
abs_up = ((fin-ini)).mean().round(2)
abs_up
# Out:
# index                           10.0
# Renta total                   8359.6
# Renta del trabajo             3704.2
# Renta capital mobiliario       585.4
# Renta capital inmobiliario     408.6
# Renta de actividades           489.6
# Transferencias                3171.8
# dtype: float64

# %%
comp_low = top_low[top_low["Año"].dt.year.isin((2011,2022))]
melt_low = comp_low.melt(id_vars=["Año","Distrito"])
comp_low
# Out:
#            Año  Renta total  Renta del trabajo  Renta capital mobiliario  \
# 28  2011-01-01      12629.0             7272.0                     270.0
# 38  2022-01-01      15863.0             9303.0                     142.0
# 54  2011-01-01      14161.0             8829.0                     627.0
# 64  2022-01-01      15996.0            10349.0                     143.0
# 249 2011-01-01       9794.0             6218.0                     123.0
# 259 2022-01-01      13362.0             7542.0                      57.0
# 353 2011-01-01      10271.0             5825.0                     265.0
# 363 2022-01-01      14009.0             7053.0                     162.0
# 457 2011-01-01      11008.0             6358.0                     289.0
# 467 2022-01-01      14092.0             7860.0                     112.0
#
#      Renta capital inmobiliario  Renta de actividades  Transferencias  \
# 28                         95.0                 538.0          4455.0
# ...

# %%
fin_low = comp_low[comp_low.columns[1:7]].iloc[1::2].reset_index()
ini_low = comp_low[comp_low.columns[1:7]].iloc[0::2].reset_index()
plot_low = ((fin_low-ini_low)/ini_low*100).mean().round(2)
plot_low
# Out:
# index                         12.65
# Renta total                   27.88
# Renta del trabajo             22.23
# Renta capital mobiliario     -55.67
# Renta capital inmobiliario    64.86
# Renta de actividades          26.98
# Transferencias                44.16
# dtype: float64

# %%
fin_low = comp_low[comp_low.columns[1:7]].iloc[1::2].reset_index()
ini_low = comp_low[comp_low.columns[1:7]].iloc[0::2].reset_index()
abs_low = ((fin_low-ini_low)).mean().round(2)
abs_low
# Out:
# index                           10.0
# Renta total                   3091.8
# Renta del trabajo             1521.0
# Renta capital mobiliario      -191.6
# Renta capital inmobiliario      45.2
# Renta de actividades           107.6
# Transferencias                1609.6
# dtype: float64

# %%
comp_bilbo = bilbo[(bilbo["Año"].dt.year.isin((2011,2022))) & (bilbo["Distrito"] == "BILBAO")]
melt_bilbo = comp_bilbo.melt(id_vars=["Año","Distrito"])
comp_bilbo
# Out:
#           Año  Renta total  Renta del trabajo  Renta capital mobiliario  \
# 2  2011-01-01      19787.0            12062.0                    1717.0
# 12 2022-01-01      25366.0            14545.0                    1780.0
#
#     Renta capital inmobiliario  Renta de actividades  Transferencias  \
# 2                        417.0                 954.0          4638.0
# 12                       623.0                1236.0          7181.0
#
#     Renta disponible Distrito
# 2            16520.0   BILBAO
# 12           20849.0   BILBAO

# %%
fin_bilbo = comp_bilbo[comp_bilbo.columns[1:7]].iloc[1::2].reset_index()
ini_bilbo = comp_bilbo[comp_bilbo.columns[1:7]].iloc[0::2].reset_index()
plot_bilbo = ((fin_bilbo-ini_bilbo)/ini_bilbo*100).mean().round(2)
plot_bilbo[1:]
# Out:
# Renta total                   28.20
# Renta del trabajo             20.59
# Renta capital mobiliario       3.67
# Renta capital inmobiliario    49.40
# Renta de actividades          29.56
# Transferencias                54.83
# dtype: float64

# %%
fin_bilbo = comp_bilbo[comp_bilbo.columns[1:7]].iloc[1::2].reset_index()
ini_bilbo = comp_bilbo[comp_bilbo.columns[1:7]].iloc[0::2].reset_index()
abs_bilbo = ((fin_bilbo-ini_bilbo)).mean().round(2)
abs_bilbo[1:]
# Out:
# Renta total                   5579.0
# Renta del trabajo             2483.0
# Renta capital mobiliario        63.0
# Renta capital inmobiliario     206.0
# Renta de actividades           282.0
# Transferencias                2543.0
# dtype: float64

# %%
abs_up = pd.DataFrame(abs_up)
abs_bilbo = pd.DataFrame(abs_bilbo)
abs_low = pd.DataFrame(abs_low)
graf_abs = pd.concat([abs_up,abs_bilbo,abs_low],axis = 1,ignore_index=True)
graf_abs
graf_abs = graf_abs.T
graf_abs["Categoria"] = ["5 arriba", "BILBAO", "5 abajo"]
graf_abs
# Out:
#    index  Renta total  Renta del trabajo  Renta capital mobiliario  \
# 0   10.0       8359.6             3704.2                     585.4
# 1   10.0       5579.0             2483.0                      63.0
# 2   10.0       3091.8             1521.0                    -191.6
#
#    Renta capital inmobiliario  Renta de actividades  Transferencias Categoria
# 0                       408.6                 489.6          3171.8  5 arriba
# 1                       206.0                 282.0          2543.0    BILBAO
# 2                        45.2                 107.6          1609.6   5 abajo

# %%
plot_up = pd.DataFrame(plot_up)
plot_bilbo = pd.DataFrame(plot_bilbo)
plot_low = pd.DataFrame(plot_low)
graf = pd.concat([plot_up,plot_bilbo,plot_low],axis = 1,ignore_index=True)
graf = graf.T
graf["Categoria"] = ["5 arriba", "BILBAO", "5 abajo"]
graf
# Out:
#     index  Renta total  Renta del trabajo  Renta capital mobiliario  \
# 0   19.08        30.10              22.63                      7.91
# 1  500.00        28.20              20.59                      3.67
# 2   12.65        27.88              22.23                    -55.67
#
#    Renta capital inmobiliario  Renta de actividades  Transferencias Categoria
# 0                       55.53                 23.94           65.36  5 arriba
# 1                       49.40                 29.56           54.83    BILBAO
# 2                       64.86                 26.98           44.16   5 abajo

# %%
graf = graf[graf.columns[1:]].melt(id_vars= "Categoria")

# %%
graf
# Out:
#    Categoria                    variable  value
# 0   5 arriba                 Renta total  30.10
# 1     BILBAO                 Renta total  28.20
# 2    5 abajo                 Renta total  27.88
# 3   5 arriba           Renta del trabajo  22.63
# 4     BILBAO           Renta del trabajo  20.59
# 5    5 abajo           Renta del trabajo  22.23
# 6   5 arriba    Renta capital mobiliario   7.91
# 7     BILBAO    Renta capital mobiliario   3.67
# 8    5 abajo    Renta capital mobiliario -55.67
# 9   5 arriba  Renta capital inmobiliario  55.53
# 10    BILBAO  Renta capital inmobiliario  49.40
# 11   5 abajo  Renta capital inmobiliario  64.86
# 12  5 arriba        Renta de actividades  23.94
# 13    BILBAO        Renta de actividades  29.56
# 14   5 abajo        Renta de actividades  26.98
# 15  5 arriba              Transferencias  65.36
# 16    BILBAO              Transferencias  54.83
# 17   5 abajo              Transferencias  44.16

# %%
plt.figure(figsize=(20,10))
sns.barplot(data = graf, x = "variable", y = "value", hue = "Categoria")
plt.xticks(rotation = 45)
plt.ylabel("Variación (%)")
plt.xlabel("Tipo de renta")
plt.title("Variación porcentual entre inicio y fin del periodo según el tipo de renta (2011-2022)");

# %%
graf_abs = graf_abs[graf_abs.columns[1:]].melt(id_vars="Categoria")
graf_abs
# Out:
#    Categoria                    variable   value
# 0   5 arriba                 Renta total  8359.6
# 1     BILBAO                 Renta total  5579.0
# 2    5 abajo                 Renta total  3091.8
# 3   5 arriba           Renta del trabajo  3704.2
# 4     BILBAO           Renta del trabajo  2483.0
# 5    5 abajo           Renta del trabajo  1521.0
# 6   5 arriba    Renta capital mobiliario   585.4
# 7     BILBAO    Renta capital mobiliario    63.0
# 8    5 abajo    Renta capital mobiliario  -191.6
# 9   5 arriba  Renta capital inmobiliario   408.6
# 10    BILBAO  Renta capital inmobiliario   206.0
# 11   5 abajo  Renta capital inmobiliario    45.2
# 12  5 arriba        Renta de actividades   489.6
# 13    BILBAO        Renta de actividades   282.0
# 14   5 abajo        Renta de actividades   107.6
# 15  5 arriba              Transferencias  3171.8
# 16    BILBAO              Transferencias  2543.0
# 17   5 abajo              Transferencias  1609.6

# %%
plt.figure(figsize=(20,10))
sns.barplot(data = graf_abs, x = "variable", y = "value", hue = "Categoria")
plt.xticks(rotation = 45)
plt.ylabel("Variación total (€)")
plt.xlabel("Tipo de renta")
plt.title("Variación absoluta entre inicio y fin del periodo según el tipo de renta (2011-2022)");

# %%
plt.figure(figsize=(20,8))
plt.subplot(3,1,1)
sns.barplot(data = melt_up, x = "variable", y = "value", hue = "Año", errorbar = None)
plt.ylabel("5 más ricos")
plt.xlabel("")
plt.legend(framealpha = 0)
plt.ylim(0,45000)
plt.xticks([])
plt.subplot(3,1,2)
sns.barplot(data = melt_bilbo, x = "variable", y = "value", hue = "Año")
plt.xlabel("")
plt.ylabel("BILBAO")
plt.xticks([])
plt.legend(framealpha = 0)
plt.ylim(0,45000)
plt.subplot(3,1,3)
sns.barplot(data = melt_low, x = "variable", y = "value", hue = "Año", errorbar = None)
plt.xlabel("")
plt.ylabel("5 más pobres")
plt.legend(framealpha = 0)
plt.xticks(rotation = 45)
plt.ylim(0,45000)
plt.suptitle("Compración inicio-fin de periodo");

# %%
plt.figure(figsize=(10,12))
#plt.subplot(3,1,1)
plt.bar();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 3
#       1 plt.figure(figsize=(10,12))
#       2 #plt.subplot(3,1,1)
# ----> 3 plt.bar();
#
# TypeError: bar() missing 2 required positional arguments: 'x' and 'height'

# %%
plt.figure(figsize=(10,9))
sns.barplot(data = comp, )
# Out:
# <Axes: >
