# %%
import numpy as np
import pandas as pd

# %%
precio_bilbao = pd.read_csv("Data/alquileres_bilbao.csv", sep = ",",encoding = "Windows 1250")
precio_bilbao
# Out:
#           Mes  Precio m2 Variación mensual Variación trimestral  \
# 0    01/02/25  15.0 €/m2             0,00%                 2.4%
# 1    01/01/25  15.0 €/m2              0.8%                 5.7%
# 2    01/12/24  14.9 €/m2              1.6%                 6.3%
# 3    01/11/24  14.6 €/m2              3.2%                 5.5%
# 4    01/10/24  14.2 €/m2              1.4%                 1.8%
# ..        ...        ...               ...                  ...
# 225  01/05/06       n.d.              n.d.                 n.d.
# 226  01/04/06       n.d.              n.d.                 n.d.
# 227  01/03/06       n.d.              n.d.                 n.d.
# 228  01/02/06       n.d.              n.d.                 n.d.
# 229  01/01/06       n.d.              n.d.                 n.d.
#
#     Variación anual
# 0              8.8%
# 1              8.8%
# 2              9.2%
# 3              8.2%
# 4              6.5%
# ..              ...
# 225            n.d.
# 226            n.d.
# ...

# %%
precio_bilbao["Mes"] = pd.to_datetime(precio_bilbao["Mes"])
precio_bilbao
# Out:
#            Mes  Precio m2 Variación mensual Variación trimestral  \
# 0   2025-01-02  15.0 €/m2             0,00%                 2.4%
# 1   2025-01-01  15.0 €/m2              0.8%                 5.7%
# 2   2024-01-12  14.9 €/m2              1.6%                 6.3%
# 3   2024-01-11  14.6 €/m2              3.2%                 5.5%
# 4   2024-01-10  14.2 €/m2              1.4%                 1.8%
# ..         ...        ...               ...                  ...
# 225 2006-01-05       n.d.              n.d.                 n.d.
# 226 2006-01-04       n.d.              n.d.                 n.d.
# 227 2006-01-03       n.d.              n.d.                 n.d.
# 228 2006-01-02       n.d.              n.d.                 n.d.
# 229 2006-01-01       n.d.              n.d.                 n.d.
#
#     Variación anual
# 0              8.8%
# 1              8.8%
# 2              9.2%
# 3              8.2%
# 4              6.5%
# ..              ...
# 225            n.d.
# ...
