# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from dateutil import parser

# %%
capitales = pd.read_csv("Data/renta_capitales.csv")
capitales
# Out:
#            Año  Renta total  Renta del trabajo  Renta capital mobiliario  \
# 0   2006-01-01      18196.0            10749.0                    2315.0
# 1   2009-01-01      20081.0            12285.0                    2000.0
# 2   2011-01-01      19787.0            12062.0                    1717.0
# 3   2013-01-01      19717.0            11735.0                    1613.0
# 4   2014-01-01      19761.0            11737.0                    1484.0
# 5   2015-01-01      20313.0            11734.0                    1403.0
# 6   2016-01-01      20526.0            11855.0                    1467.0
# 7   2017-01-01      21245.0            12448.0                    1343.0
# 8   2018-01-01      21538.0            12571.0                    1394.0
# 9   2019-01-01      22659.0            13304.0                    1441.0
# 10  2020-01-01      22464.0            12656.0                    1357.0
# 11  2021-01-01      23592.0            13491.0                    1461.0
# ...

# %%
capitales["Año"] = pd.to_datetime(capitales["Año"])

# %%
capitales.dtypes
# Out:
# Año                           datetime64[ns]
# Renta total                          float64
# Renta del trabajo                    float64
# Renta capital mobiliario             float64
# Renta capital inmobiliario           float64
# Renta de actividades                 float64
# Transferencias                       float64
# Renta disponible                     float64
# Ciudad                                object
# dtype: object

# %%
ipc = pd.read_csv("Data/ipc_ok.csv")
ipc
# Out:
#     Unnamed: 0 Comunidades y Ciudades Autónomas  \
# 0            0                    16 País Vasco
# 1            1                    16 País Vasco
# 2            2                    16 País Vasco
# 3            3                    16 País Vasco
# 4            4                    16 País Vasco
# 5            5                    16 País Vasco
# 6            6                    16 País Vasco
# 7            7                    16 País Vasco
# 8            8                    16 País Vasco
# 9            9                    16 País Vasco
# 10          10                    16 País Vasco
# 11          11                    16 País Vasco
# 12          12                    16 País Vasco
# 13          13                    16 País Vasco
# 14          14                    16 País Vasco
# 15          15                    16 País Vasco
# 16          16                    16 País Vasco
# 17          17                    16 País Vasco
# ...

# %%
ipc["Periodo"] = pd.to_datetime(ipc["Periodo"])
ipc.dtypes
# Out:
# Unnamed: 0                                   int64
# Comunidades y Ciudades Autónomas            object
# Grupos ECOICOP                              object
# Tipo de dato                                object
# Periodo                             datetime64[ns]
# Total                                      float64
# dtype: object

# %%
plt.figure(figsize=(10,9));
sns.lineplot(data = capitales, x = "Año", y = "Renta total", hue = "Ciudad")
#sns.lineplot(data = capitales, x = "Año", y = "Renta del trabajo", hue = "Ciudad")
plt.xticks(rotation = "vertical");

# %%
triang = capitales.iloc[13:,1:-1].corr()
mascara = np.triu(np.ones_like(triang,dtype=bool),1)
mascara
# Out:
# array([[False,  True,  True,  True,  True,  True,  True],
#        [False, False,  True,  True,  True,  True,  True],
#        [False, False, False,  True,  True,  True,  True],
#        [False, False, False, False,  True,  True,  True],
#        [False, False, False, False, False,  True,  True],
#        [False, False, False, False, False, False,  True],
#        [False, False, False, False, False, False, False]])

# %%
f, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(capitales.iloc[:,1:-1].corr(),
            mask = mascara,
            annot=True,
            linewidths=.5,
            ax=ax,
            vmin=0,
            vmax=1,
            cmap = "Greens")
plt.title("Tipos de Renta en las capitales de provincia");

# %%
plt.figure(figsize=(10,9));
#sns.lineplot(data = capitales, x = "Año", y = "Renta total", hue = "Ciudad")
sns.lineplot(data = capitales, x = "Año", y = "Renta capital inmobiliario", hue = "Ciudad")
plt.xticks(rotation = "vertical");
